# %%
import numpy as np
import pandas as pd
import requests
import urllib
import sqlite3
# import libraries
import geopandas as gpd
from shapely.geometry import Point, Polygon
import matplotlib.pyplot as plt

# %%
con = sqlite3.connect("switrs.sqlite")

# %%
coll = ('''SELECT latitude, longitude FROM collisions
         WHERE latitude IS NOT NULL AND longitude IS NOT NULL
         
       ''' )

df = pd.read_sql_query(coll, con)
df
# Out:
#          latitude  longitude
# 0        39.61953 -121.69178
# 1        37.82839 -120.63505
# 2        38.28533 -121.45608
# 3        38.52921 -121.33477
# 4        38.56349 -121.49161
# ...           ...        ...
# 2523806  34.44470 -117.39960
# 2523807  34.95313 -120.41725
# 2523808  33.43440 -117.47220
# 2523809  37.44952 -122.18463
# 2523810  37.22209 -121.50213
#
# [2523811 rows x 2 columns]

# %%
import requests
import urllib
      
lat = 33.91639
lon = -118.32651


#Encode parameters 
params = urllib.parse.urlencode({'latitude': lat, 'longitude':lon, 'format':'json'})
#Contruct request URL
url = 'https://geo.fcc.gov/api/census/block/find?' + params

#Get response from API
response = requests.get(url)

#Parse json in response
data = response.json()

#Print FIPS code
print (data['County']['FIPS'])
# Out:
# 06037

# %%
query = ('''SELECT latitude,longitude, COUNT(*) as count
         FROM collisions
         GROUP BY latitude, longitude ORDER BY count DESC LIMIT 50
         ''' )

df = pd.read_sql_query(query, con)
df
# Out:
#     latitude  longitude    count
# 0        NaN        NaN  6648753
# 1   38.49347 -121.54347      756
# 2   38.00000 -121.00000      444
# 3   33.02186 -117.27314      206
# 4   38.00000 -122.00000      169
# 5   39.50936 -121.55453      124
# 6   37.98924 -121.32156      119
# 7   37.98517 -121.33952      117
# 8   38.02093 -121.29518      114
# 9   38.56438 -121.49347      113
# 10  33.91639 -118.32651      110
# 11  38.02123 -121.35652      104
# 12  38.00207 -121.29015       98
# 13  33.00000 -117.00000       95
# 14  37.99149 -121.31228       92
# 15  38.61852 -121.26816       91
# 16  33.77300 -116.95869       89
# 17  33.98304 -117.34004       88
# 18  33.62120 -117.87010       87
# 19  35.62362 -117.68640       85
# 20  34.00000 -118.00000       83
# 21  38.02116 -121.31549       81
# 22  37.98682 -121.32039       80
# 23  37.99638 -121.30507       80
# 24  38.59377 -121.28796       80
# 25  33.92371 -118.32647       77
# 26  33.78021 -116.97188       75
# ...

# %%
import plotly.figure_factory as ff

fips = ['06067', '06077', '06073',
        '06013', '06007', '06077',
        '06077', '06077', '06067',
        '06037']
values = range(len(fips))

fig = ff.create_choropleth(fips=fips, values=values, scope = ['CA'])
fig.layout.template = None
fig.show()

#06067 = 1st, 9th - sacramento county
#06077- 2nd , 6th, 7th, 8th - san joaquin county
#06073 - 3rd san diego county
#06013 - 4th contra costa county
#06007 5th butte county
#06037  10 LA county

-ask coloring?
# Out:
# <div>                            <div id="e7dd9472-7419-48d4-a751-8c40a9dae8a6" class="plotly-graph-div" style="height:450px; width:900px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e7dd9472-7419-48d4-a751-8c40a9dae8a6")) {                    Plotly.newPlot(                        "e7dd9472-7419-48d4-a751-8c40a9dae8a6",                        [{"fill": "toself", "fillcolor": "rgb(68, 1, 84)", "hoverinfo": "none", "line": {"color": "rgb(0, 0, 0)", "width": 0}, "mode": "lines", "name": "0", "type": "scatter", "x": [-121.86254199999999, -121.710888, -121.685586, -121.612102, -121.583954, -121.520777, -121.532696, -121.504139, -121.559167, -121.507241, -121.63019, -121.60289399999999, -121.118617, -121.027472, -121.027084, -121.34402399999999, -121.470958, -121.584074, -121.567184, -121.673065, -121.69976
# ...

# %%
import plotly.figure_factory as ff

fips = ['06077', '06067', '06073',
        '06013', '06007', '06037']
values = range(len(fips))

fig = ff.create_choropleth(fips=fips, values=values, scope = ['CA'])
fig.layout.template = None
fig.show()

#06067 = 2- sacramento county lighter purple
#06077- 1 san joaquin dark purple
#06073 - 3rd san diego county dark blue
#06013 - 4th contra costa county turquoise
#06007 5th butte county green
#06037  6 LA county yellow

#density:  most dense (SF 3575/sqmi) Orange(3255 /sqmi) LA(2099sq mi) Alameda(1898/sqmi, Sacramento 5th 1459/sqmi)

#San Joaquin - #10 in density 491/sq mi, San Diego - 9 703/sqmi  Contra Costa - 7 1345/sqmi  Butte - 24 132/sqmi
# Out:
# <div>                            <div id="38ad23d6-8656-471e-90b5-faa0389b2e71" class="plotly-graph-div" style="height:450px; width:900px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("38ad23d6-8656-471e-90b5-faa0389b2e71")) {                    Plotly.newPlot(                        "38ad23d6-8656-471e-90b5-faa0389b2e71",                        [{"fill": "toself", "fillcolor": "rgb(68, 1, 84)", "hoverinfo": "none", "line": {"color": "rgb(0, 0, 0)", "width": 0}, "mode": "lines", "name": "0", "type": "scatter", "x": [-121.584719, -121.564035, -121.584074, -121.472625, -121.34402399999999, -121.027084, -120.92644899999999, -120.920599, -120.99276, -121.110208, -121.471925, -121.556655, -121.557038, -121.534247, -121.578965, -121.556419, -121.57991, -121.557554, -121.584719, null], "y": [38.043545, 38.10142
# ...

# %%
# import ca map
ca_map = gpd.read_file('/Users/rena/desktop/class/Capstone1/Collision Data/Maps/c_10nv20.shp')
ca_map
# Out:
#      STATE  CWA     COUNTYNAME   FIPS TIME_ZONE FE_AREA       LON      LAT  \
# 0       ME  CAR     Washington  23029         E      se  -67.6361  45.0363
# 1       GA  CHS       McIntosh  13191         E      se  -81.2646  31.5329
# 2       GA  CHS        Liberty  13179         E      se  -81.2103  31.7093
# 3       AS  PPG  Swains Island  60040         S    None -171.0459 -11.0843
# 4       AS  PPG         Manu'a  60020         S    None -169.5060 -14.2219
# ...    ...  ...            ...    ...       ...     ...       ...      ...
# 3318    VA  AKQ           York  51199         E      se  -76.5637  37.2371
# 3319    TX  BRO         Kenedy  48261         C      ds  -97.7174  26.9281
# 3320    TX  BRO        Willacy  48489         C      ds  -97.6732  26.4706
# 3321    MI  APX       Chippewa  26033         E      ee  -84.5921  46.3031
# 3322    OR  MFR          Curry  41015         P      sw -124.1567  42.4578
#
#                                                geometry
# ...

# %%
# designate coordinate system
#crs={‘init’:’espc:4326'}
CRS:EPSG:4326
#my_geoseries = my_geoseries.set_crs(epsg=4326)
# zip x and y coordinates into single feature
geometry = [Point(xy) for xy in zip(df['longitude'], df['latitude' ])]                                                  
# create GeoPandas dataframe
geo_df = gpd.GeoDataFrame(df,
my_geoseries = my_geoseries,
 geometry = geometry)
# Out:
#   File "<ipython-input-50-bdf168703519>", line 3
#     CRS:EPSG:4326
#             ^
# SyntaxError: invalid syntax

# %%
geo_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-52-40ec50a66a08> in <module>
# ----> 1 geo_df.head()
#       2
#       3
#
# NameError: name 'geo_df' is not defined

# %%
# create figure and axes, assign to subplot
fig, ax = plt.subplots(figsize=(15,15))
# add .shp mapfile to axes
street_map.plot(ax=ax, alpha=0.4,color=’grey’)
# add geodataframe to axes
# assign ‘price’ variable to represent coordinates on graph
# add legend
# make datapoints transparent using alpha
# assign size of points using markersize
geo_df.plot(column=’price’,ax=ax,alpha=0.5, legend=True,markersize=10)
# add title to graph
plt.title(‘Rental Prices in NYC’, fontsize=15,fontweight=’bold’)
# set latitiude and longitude boundaries for map display
plt.xlim(-74.02,-73.925)
plt.ylim( 40.7,40.8)
# show map
plt.show()

# %%
with urlopen('https://raw.githubusercontent.com/plotly/datasets/master/geojson-counties-fips.json') as response:
    counties['features'] = [c for c in counties['features'] if c['properties']['STATE'] == '06']
    
    #counties = json.load(response)
    
    
{'type': 'Feature',
 'properties': {'GEO_ID': '0500000US01001',
  'STATE': '06',
  'COUNTY': '001',
  'NAME': 'Autauga',
  'LSAD': 'County',
  'CENSUSAREA': 594.436},
 'geometry': {'type': 'Polygon',
  'coordinates': [[[-86.496774, 32.344437],
    [-86.717897, 32.402814],
    [-86.814912, 32.340803],
    [-86.890581, 32.502974],
    [-86.917595, 32.664169],
    [-86.71339, 32.661732],
    [-86.714219, 32.705694],
    [-86.413116, 32.707386],
    [-86.411172, 32.409937],
    [-86.496774, 32.344437]]]},
 'id': '01001'}



fig = px.choropleth(df, geojson=counties, locations='fips', color='unemp',
                           color_continuous_scale="Viridis",
                           range_color=(0, 12),
                           #scope="usa",
                           labels={'unemp':'unemployment rate'}
                          )



#fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-60-4207066dd06f> in <module>
# ----> 1 with urlopen('https://raw.githubusercontent.com/plotly/datasets/master/geojson-counties-fips.json') as response:
#       2     counties['features'] = [c for c in counties['features'] if c['properties']['STATE'] == '06']
#       3
#       4     #counties = json.load(response)
#       5
#
# NameError: name 'urlopen' is not defined

# %%
import urllib, json, requests

with urllib.request.urlopen("https://geo.fcc.gov/api/census/area?lat=42.3295&lon=-71.0826&format=json") as url:
    data = json.loads(url.read().decode())
    print(data)

print(json.dumps(data, indent=4, sort_keys=True))

print(data['results'][0]['state_fips'])
print(data['results'][0]['county_fips'])
print(data['results'][0]['county_name'])
# Out:
# {'input': {'lat': 42.3295, 'lon': -71.0826}, 'results': [{'block_fips': '250250804011018', 'bbox': [-71.083358, 42.329297, -71.082166, 42.330103], 'county_fips': '25025', 'county_name': 'Suffolk', 'state_fips': '25', 'state_code': 'MA', 'state_name': 'Massachusetts', 'block_pop_2015': 10, 'amt': 'AMT001', 'bea': 'BEA003', 'bta': 'BTA051', 'cma': 'CMA006', 'eag': 'EAG001', 'ivm': 'IVM006', 'mea': 'MEA001', 'mta': 'MTA008', 'pea': 'PEA007', 'rea': 'REA001', 'rpc': 'RPC001', 'vpc': 'VPC001'}]}
# {
#     "input": {
#         "lat": 42.3295,
#         "lon": -71.0826
#     },
#     "results": [
#         {
#             "amt": "AMT001",
#             "bbox": [
#                 -71.083358,
#                 42.329297,
#                 -71.082166,
#                 42.330103
#             ],
#             "bea": "BEA003",
#             "block_fips": "250250804011018",
#             "block_pop_2015": 10,
#             "bta": "BTA051",
#             "cma": "CMA006",
# ...
